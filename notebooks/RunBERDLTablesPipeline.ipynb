# %% [markdown]
# # Run BERDL Tables Pipeline
#
# This notebook runs the BERDL tables pipeline outside the KBase container.
# It uses `util.py` as a proxy for `KBDatalakeAppsImpl`, replicating
# how the deployed app initializes `KBDataLakeUtils` and imports the same
# standalone worker functions (`run_model_reconstruction`, `run_phenotype_simulation`).
#
# **Workflow:**
# 1. **Cell 1**: Create scratch directory, write `input_params.json`, print container commands, annotate pangenome FAA files with RAST
# 2. **Cell 2**: Convert user genome to TSV, run model reconstruction + phenotype simulation in parallel

# %%
# %run util.py
import os
import json
from pathlib import Path

# ---- EDIT THESE PARAMETERS ----
workspace_id = "76990"
genome_name = "Acinetobacter_baylyi_ADP1_RAST"
# --------------------------------

genome_ref = f"{workspace_id}/{genome_name}"

parameters = {
    "workspace_id": workspace_id,
    "genome_name": genome_name,
}

sdk_config = {
    "kbversion":"appdev",
    "scratch":"/kb/module/work/shared/chenry/scratch",
    "reference_path": "/data",
    "module_path": "/kb/module/work/shared/chenry",
    "max_phenotypes": 5,
    "experimental_phenotype_datafile":"/kb/module/data/experimental_data.json",
    "phenotypeset_file":"/kb/module/data/full_phenotype_set.json",
    "fitness_genomes_dir":"/data/reference_data/phenotype_data/fitness_genomes/",
    "reference_phenosim_dir":"/data/reference_data/phenotype_data/phenosims",
    "experimental_essentiality_datafile":"/kb/module/data/essential_genes.csv"
}

poplar_config = {
    "kbversion":"appdev",
    "scratch":"/home/chenry/BERDLFiles/scratch",
    "reference_path": "/home/chenry/GSP",
    "module_path": "/home/chenry/BERDLFiles",
    "max_phenotypes": 5,
    "experimental_phenotype_datafile":"/home/chenry/Dropbox/Projects/KBDatalakeApps/data/experimental_data.json",
    "phenotypeset_file":"/home/chenry/Dropbox/Projects/KBDatalakeApps/data/full_phenotype_set.json",
    "fitness_genomes_dir":"/home/chenry/GSP/reference_data/phenotype_data/fitness_genomes/",
    "reference_phenosim_dir":"/home/chenry/GSP/reference_data/phenotype_data/phenosims/",
    "experimental_essentiality_datafile":"/home/chenry/Dropbox/Projects/KBDatalakeApps/data/essential_genes.csv"
}

sdk_config["output_dir"] = sdk_config["scratch"] + "/" + parameters["genome_name"]
poplar_config["output_dir"] = poplar_config["scratch"] + "/" + parameters["genome_name"]

util.save("parameters", parameters)
util.save("sdk_config", sdk_config)
util.save("poplar_config", poplar_config)

# Write input_params.json (mirrors how Impl creates the parameter file)
token = util.get_token('kbase')
input_params = {
    "input_refs": [genome_ref],
    "_ctx": {"token": token},
    "_config": {"scratch": sdk_config["output_dir"]}
}
output_dir = Path(poplar_config["output_dir"])
output_dir.mkdir(parents=True, exist_ok=True)
params_file = output_dir / "input_params.json"
with open(params_file, 'w') as f:
    json.dump(input_params, f, indent=2)
print(f"Wrote: {params_file}")

# Remind user of container commands
print("\n" + "=" * 70)
print("Run this commands in the container BEFORE continuing to the next cell:")
print(f'  {sdk_config["module_path"]}/KBDatalakeApps/scripts/run_genome_pipeline.sh {sdk_config["output_dir"]}/input_params.json')
print("=" * 70)
# Out:
# [KBUtilLib] Failed to import rcsb_pdb_utils: ModuleNotFoundError: No module named 'aiohttp'
# modelseedpy 0.4.2
# 2026-02-14 14:58:55,495 - __main__.NotebookUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-14 14:58:55,496 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-14 14:58:55,497 - __main__.NotebookUtil - INFO - Notebook name: RunBERDLTablesPipeline
# 2026-02-14 14:58:55,498 - __main__.NotebookUtil - INFO - Notebook environment detected
# Wrote: /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/input_params.json
#
# ======================================================================
# Run this commands in the container BEFORE continuing to the next cell:
#   /kb/module/work/shared/chenry/KBDatalakeApps/scripts/run_genome_pipeline.sh /kb/module/work/shared/chenry/scratch/Acinetobacter_baylyi_ADP1_RAST/input_params.json
# ======================================================================

# %%
# %run util.py
from pathlib import Path

parameters = util.load("parameters")
sdk_config = util.load("sdk_config")
poplar_config = util.load("poplar_config")
output_dir = Path(poplar_config["output_dir"])

# Discover pangenome clade ID from the folder created by run_genome_pipeline.sh
pangenome_dir = output_dir / "pangenome"
if pangenome_dir.exists():
    clade_folders = [d.name for d in pangenome_dir.iterdir() if d.is_dir()]
    if len(clade_folders) == 1:
        pangenome_clade_id = clade_folders[0]
    elif len(clade_folders) > 1:
        print(f"Multiple pangenome clades found: {clade_folders}")
        pangenome_clade_id = clade_folders[0]
        print(f"Using first: {pangenome_clade_id}")
    else:
        raise FileNotFoundError(f"No clade subdirectories found in {pangenome_dir}")
else:
    raise FileNotFoundError(
        f"{pangenome_dir} does not exist. Run the genome pipeline first:\n"
        f'  {sdk_config["module_path"]}/KBDatalakeApps/scripts/run_genome_pipeline.sh {sdk_config["output_dir"]}/input_params.json'
    )

print(f"Detected pangenome clade ID: {pangenome_clade_id}")
sdk_config["pangenome_clade_id"] = pangenome_clade_id
poplar_config["pangenome_clade_id"] = pangenome_clade_id
util.save("sdk_config", sdk_config)
util.save("poplar_config", poplar_config)

print("\n" + "=" * 70)
print("Run these commands in the container BEFORE continuing to the next cell:")
print(f'  {sdk_config["module_path"]}/KBDatalakeApps/scripts/run_pangenome_pipeline.sh {sdk_config["output_dir"]}/input_params.json {pangenome_clade_id}')
print("=" * 70)
print(f'  {sdk_config["module_path"]}/KBDatalakeApps/scripts/build_pangenome_data_tsv.sh {sdk_config["output_dir"]} {pangenome_clade_id}')
print("=" * 70)
# Out:
# 2026-02-12 22:12:18,115 - __main__.NotebookUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:12:18,116 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:12:18,118 - __main__.NotebookUtil - INFO - Notebook name: RunBERDLTablesPipeline
# 2026-02-12 22:12:18,119 - __main__.NotebookUtil - INFO - Notebook environment detected
# Detected pangenome clade ID: RS_GCF_000368685.1
#
# ======================================================================
# Run these commands in the container BEFORE continuing to the next cell:
#   /kb/module/work/shared/chenry/KBDatalakeApps/scripts/run_pangenome_pipeline.sh /kb/module/work/shared/chenry/scratch/Acinetobacter_baylyi_ADP1_RAST/input_params.json RS_GCF_000368685.1
# ======================================================================
#   /kb/module/work/shared/chenry/KBDatalakeApps/scripts/build_pangenome_data_tsv.sh /kb/module/work/shared/chenry/scratch/Acinetobacter_baylyi_ADP1_RAST/RS_GCF_000368685.1
# ======================================================================

# %%
# %run util.py
from pathlib import Path

parameters = util.load("parameters")
poplar_config = util.load("poplar_config")
output_dir = Path(poplar_config["output_dir"])

# Annotate user genome FAA files with RAST (robust to genomes without RAST annotation)
user_genome_dir = output_dir / "genome"
if user_genome_dir.exists():
    faa_files = sorted(user_genome_dir.glob("*.faa"))
    print(f"Found {len(faa_files)} user genome FAA files in {user_genome_dir}")
    for faa_file in faa_files:
        tsv_path = util.annotate_faa_with_rast(faa_file)
        print(f"  {faa_file.name} -> {Path(tsv_path).name}")
else:
    print(f"Warning: {user_genome_dir} does not exist yet.")

# Annotate pangenome member FAA files with RAST
genome_dir = output_dir / "pangenome" / poplar_config["pangenome_clade_id"] / "genome"
if genome_dir.exists():
    faa_files = sorted(genome_dir.glob("*.faa"))
    print(f"\nFound {len(faa_files)} pangenome FAA files in {genome_dir}")
    for faa_file in faa_files:
        tsv_path = util.annotate_faa_with_rast(faa_file)
        print(f"  {faa_file.name} -> {Path(tsv_path).name}")
else:
    print(f"\nWarning: {genome_dir} does not exist yet.")
    print("Run the pangenome pipeline command above first, then re-run this cell.")

print("\nRAST annotation complete.")
# Out:
# [KBUtilLib] Failed to import rcsb_pdb_utils: ModuleNotFoundError: No module named 'aiohttp'
# modelseedpy 0.4.2
# 2026-02-12 22:19:16,570 - __main__.NotebookUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:19:16,572 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:19:16,573 - __main__.NotebookUtil - INFO - Notebook name: RunBERDLTablesPipeline
# 2026-02-12 22:19:16,574 - __main__.NotebookUtil - INFO - Notebook environment detected
# Found 1 user genome FAA files in /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/genome
#   user_Acinetobacter_baylyi_ADP1_RAST.faa -> user_Acinetobacter_baylyi_ADP1_RAST.tsv
#
# Found 13 pangenome FAA files in /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/pangenome/RS_GCF_000368685.1/genome
#   GB_GCA_002694305.1.faa -> GB_GCA_002694305.1.tsv
#   RS_GCF_000046845.1.faa -> RS_GCF_000046845.1.tsv
#   RS_GCF_000302115.1.faa -> RS_GCF_000302115.1.tsv
#   RS_GCF_000368685.1.faa -> RS_GCF_000368685.1.tsv
#   RS_GCF_000621045.1.faa -> RS_GCF_000621045.1.tsv
#   RS_GCF_001485005.1.faa -> RS_GCF_001485005.1.tsv
#   RS_GCF_010577805.1.faa -> RS_GCF_010577805.1.tsv
#   RS_GCF_010577855.1.faa -> RS_GCF_010577855.1.tsv
#   RS_GCF_010577875.1.faa -> RS_GCF_010577875.1.tsv
#   RS_GCF_010577895.1.faa -> RS_GCF_010577895.1.tsv
#   RS_GCF_010577925.1.faa -> RS_GCF_010577925.1.tsv
#   RS_GCF_010577955.1.faa -> RS_GCF_010577955.1.tsv
#   RS_GCF_900465415.1.faa -> RS_GCF_900465415.1.tsv
#
# RAST annotation complete.

# %%
# %run util.py
import os
import traceback
from pathlib import Path
from concurrent.futures import ProcessPoolExecutor, as_completed
from KBDatalakeApps.KBDatalakeUtils import run_model_reconstruction

parameters = util.load("parameters")
poplar_config = util.load("poplar_config")

kbversion = poplar_config["kbversion"]
output_dir = Path(poplar_config["output_dir"])

genome_ref = f"{parameters['workspace_id']}/{parameters['genome_name']}"
kbdl = util.create_kbdl_utils(poplar_config["reference_path"], poplar_config["module_path"], kbversion)
classifier_dir = os.path.join("/home/chenry/Dropbox/Projects/KBUtilLib", "data", "ms_classifier")

# Step 1: Convert user genome to full-format TSV from workspace
user_genome_dir = output_dir / "genome"
user_genome_dir.mkdir(parents=True, exist_ok=True)
user_genome_tsv = user_genome_dir / f"user_{parameters['genome_name']}_kbasedump.tsv"
print(f"Converting genome {genome_ref} to TSV...")
kbdl.run_user_genome_to_tsv(genome_ref, str(user_genome_tsv))
print(f"  Wrote: {user_genome_tsv}")

# Step 2: Collect simple RAST TSVs only (exclude kbasedump, bakta, KOfamscan, PSORT, genome_data)
_skip_suffixes = ("_kbasedump.tsv", "_bakta.tsv", "_KOfamscan.tsv", "_PSORT.tsv", "_genome_data.tsv")
all_tsvs = [f for f in sorted(user_genome_dir.glob("user_*.tsv"))
            if not f.name.endswith(_skip_suffixes)]
print(f"Found {len(all_tsvs)} RAST-annotated user genome TSVs in {user_genome_dir}")

# Add pangenome member TSVs (only simple RAST files, not enriched _genome_data.tsv)
pangenome_genome_dir = output_dir / "pangenome" / poplar_config["pangenome_clade_id"] / "genome"
if pangenome_genome_dir.exists():
    rast_tsvs = [f for f in sorted(pangenome_genome_dir.glob("*.tsv"))
                 if not f.name.endswith(_skip_suffixes)]
    all_tsvs.extend(rast_tsvs)
    print(f"Found {len(rast_tsvs)} RAST-annotated TSVs in {pangenome_genome_dir}")
print(f"Total TSVs to process: {len(all_tsvs)}")

# Step 3: Build work items for parallel processing
results_dir = output_dir / "models"
results_dir.mkdir(parents=True, exist_ok=True)

work_items = []
for tsv_path in all_tsvs:
    stem = tsv_path.stem
    output_base = str(results_dir / stem)
    work_items.append((str(tsv_path), output_base))

# Step 4: Run model reconstruction in parallel (10 workers)
print(f"\n--- Model Reconstruction ({len(work_items)} genomes, 10 workers) ---")
with ProcessPoolExecutor(max_workers=10) as executor:
    futures = {
        executor.submit(run_model_reconstruction, inp, outp, classifier_dir, kbversion): (inp, outp)
        for inp, outp in work_items
    }
    for future in as_completed(futures):
        inp, outp = futures[future]
        try:
            result = future.result()
            status = "OK" if result.get('success') else f"FAIL: {str(result.get('error', '?'))[:80]}"
            print(f"  {Path(inp).name}: {status}")
        except Exception as e:
            print(f"  {Path(inp).name}: ERROR - {e}")
            traceback.print_exc()

# Summary
cobra_files = sorted(results_dir.glob("*_cobra.json"))
data_files = sorted(results_dir.glob("*_data.json"))
print(f"\nDone. {len(cobra_files)} cobra models, {len(data_files)} data files in: {results_dir}")
# Out:
# 2026-02-12 22:19:51,212 - __main__.NotebookUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:19:51,213 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:19:51,214 - __main__.NotebookUtil - INFO - Notebook name: RunBERDLTablesPipeline
# 2026-02-12 22:19:51,215 - __main__.NotebookUtil - INFO - Notebook environment detected
# 2026-02-12 22:19:51,231 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:19:51,232 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# loading biochemistry database from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:19:59,395 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:00,016 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - CRITICAL - KBase version not set up for modeling!
# cobrakbase 0.4.0
# Converting genome 76990/Acinetobacter_baylyi_ADP1_RAST to TSV...
#   Wrote: /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/genome/user_Acinetobacter_baylyi_ADP1_RAST_kbasedump.tsv
# Found 1 RAST-annotated user genome TSVs in /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/genome
# Found 13 RAST-annotated TSVs in /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/pangenome/RS_GCF_000368685.1/genome
# Total TSVs to process: 14
#
# --- Model Reconstruction (14 genomes, 10 workers) ---
# 2026-02-12 22:20:03,825 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,824 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,825 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,825 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,825 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,825 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,825 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,825 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,825 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,825 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-12 22:20:03,828 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,828 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,829 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,830 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,830 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,830 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,831 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,831 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,832 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,832 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-12 22:20:03,833 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:03,833 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:03,833 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:03,834 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:03,834 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:03,834 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:03,835 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:03,834 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:03,835 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-12 22:20:03,836 - kbutillib.ms_reconstruction_utils.MSReconstructionUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# genome_id: user_Acinetobacter_baylyi_ADP1_RASTgenome_id: RS_GCF_010577855.1genome_id: RS_GCF_000368685.1
#
#
# genome_id: RS_GCF_010577805.1
# genome_id: RS_GCF_000621045.1genome_id: RS_GCF_001485005.1
#
# TSV format detected: simple (id, function)
# TSV format detected: simple (id, function)genome_id: RS_GCF_010577875.1
#
# TSV format detected: simple (id, function)
# genome_id: GB_GCA_002694305.1
# genome_id: RS_GCF_000302115.1TSV format detected: simple (id, function)
# genome_id: RS_GCF_000046845.1
#
# TSV format detected: simple (id, function)
# TSV format detected: simple (id, function)
# TSV format detected: simple (id, function)
# TSV format detected: simple (id, function)
# TSV format detected: simple (id, function)
# TSV format detected: simple (id, function)
#   Genome user_Acinetobacter_baylyi_ADP1_RAST: 3209 features, 3146 with RAST annotations
#   Genome RS_GCF_000368685.1: 3275 features, 3190 with RAST annotations
#   Genome RS_GCF_000621045.1: 3318 features, 3220 with RAST annotations
#   Genome RS_GCF_010577855.1: 3276 features, 3175 with RAST annotations
#   Genome GB_GCA_002694305.1: 3617 features, 3335 with RAST annotations
#   Genome RS_GCF_010577805.1: 3285 features, 3184 with RAST annotations  Genome RS_GCF_000302115.1: 3465 features, 3329 with RAST annotations
#
#   Genome RS_GCF_010577875.1: 3292 features, 3188 with RAST annotations  Genome RS_GCF_000046845.1: 3273 features, 3189 with RAST annotations
#
#   Genome RS_GCF_001485005.1: 3311 features, 3207 with RAST annotations
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/env/modelseed_cplex/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.2.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# N
# N
# NN
#
# N
# NN
#
# N
# N
# N
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Etho activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for mal-L activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for H2.SO4 activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for empty activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Light activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for ANME activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# WARNING:modelseedpy.core.msgapfill:No gapfilling solution found before filtering for Methane activating rxn00062_c0
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d876e09a0>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855c04f0>, 'is_max_threshold': True, 'threshold': 7.799999999999997, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8559a5f0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8556eec0>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855201c0>, 'is_max_threshold': True, 'threshold': 16.2, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856c40a0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8569d420>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856777f0>, 'is_max_threshold': True, 'threshold': 2.25, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856502b0>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857a7b80>, 'is_max_threshold': True, 'threshold': 1.5, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858ddea0>, 'is_max_threshold': True, 'threshold': 0.09999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858ac3a0>, 'is_max_threshold': True, 'threshold': 0.75, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85863b20>, 'is_max_threshold': True, 'threshold': 1.700000000000011, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d87779d80>, 'is_max_threshold': True, 'threshold': 4.95, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8777a2c0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8777a500>, 'is_max_threshold': True, 'threshold': 1.8000000000001368, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d87779a50>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d87779510>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d87779060>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d87778ac0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}]
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d879c5120>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d854fc4f0>, 'is_max_threshold': True, 'threshold': 7.799999999999997, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856ce7d0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856a4220>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8565bca0>, 'is_max_threshold': True, 'threshold': 16.2, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856057b0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857d6bf0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857d5f30>, 'is_max_threshold': True, 'threshold': 2.25, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8575c490>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85738fd0>, 'is_max_threshold': True, 'threshold': 1.5, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857f1f60>, 'is_max_threshold': True, 'threshold': 0.09999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d859c0160>, 'is_max_threshold': True, 'threshold': 0.75, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85972aa0>, 'is_max_threshold': True, 'threshold': 1.700000000000011, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85972ce0>, 'is_max_threshold': True, 'threshold': 4.95, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8594d0c0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858f9990>, 'is_max_threshold': True, 'threshold': 1.8000000000001368, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85521ff0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85548730>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855774f0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85576470>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}]
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d87f19ba0>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855142e0>, 'is_max_threshold': True, 'threshold': 7.800000000000409, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d854f57e0>, 'is_max_threshold': True, 'threshold': 14.699999999998157, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856c1600>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85671210>, 'is_max_threshold': True, 'threshold': 16.2, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85621750>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855fd1e0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857cfb20>, 'is_max_threshold': True, 'threshold': 2.25, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85780670>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8572bc40>, 'is_max_threshold': True, 'threshold': 1.5, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85809150>, 'is_max_threshold': True, 'threshold': 0.10000000000004547, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d859dd450>, 'is_max_threshold': True, 'threshold': 0.75, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d859b7fa0>, 'is_max_threshold': True, 'threshold': 1.7000000000005002, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8598dc90>, 'is_max_threshold': True, 'threshold': 4.949999999999863, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85961720>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85915900>, 'is_max_threshold': True, 'threshold': 1.8000000000004093, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8553e860>, 'is_max_threshold': True, 'threshold': 0.5999999999999999, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85566da0>, 'is_max_threshold': True, 'threshold': 0.5999999999999999, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85590e50>, 'is_max_threshold': True, 'threshold': 0.5999999999999999, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855b9510>, 'is_max_threshold': True, 'threshold': 0.5999999999999999, 'objective': 'rxn00062_c0'}]
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d879d5cc0>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85577430>, 'is_max_threshold': True, 'threshold': 7.8, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855494b0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85522170>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856c8190>, 'is_max_threshold': True, 'threshold': 16.2, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85657be0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856561a0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8562d720>, 'is_max_threshold': True, 'threshold': 2.25, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857d5630>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8578a740>, 'is_max_threshold': True, 'threshold': 1.5, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85867550>, 'is_max_threshold': True, 'threshold': 0.09999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8583a860>, 'is_max_threshold': True, 'threshold': 0.75, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857edea0>, 'is_max_threshold': True, 'threshold': 1.6999999999998863, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857ee620>, 'is_max_threshold': True, 'threshold': 4.95, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d859c1d50>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8596c280>, 'is_max_threshold': True, 'threshold': 1.7999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8559f160>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855c4fa0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d879d4520>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d879d4610>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}]
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d874bb1c0>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855b0b50>, 'is_max_threshold': True, 'threshold': 7.8, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85588d90>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85561a20>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855172e0>, 'is_max_threshold': True, 'threshold': 16.200000000001772, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856b8b80>, 'is_max_threshold': True, 'threshold': 14.700000000001772, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85697400>, 'is_max_threshold': True, 'threshold': 14.700000000001772, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8566d390>, 'is_max_threshold': True, 'threshold': 2.250000000000682, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855fae60>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857c6860>, 'is_max_threshold': True, 'threshold': 1.5, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858d2080>, 'is_max_threshold': True, 'threshold': 0.09999999999990905, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858a5780>, 'is_max_threshold': True, 'threshold': 0.7499999999989085, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85857b80>, 'is_max_threshold': True, 'threshold': 1.7000000000006366, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85826410>, 'is_max_threshold': True, 'threshold': 4.95, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85824fd0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d859d0e50>, 'is_max_threshold': True, 'threshold': 1.7999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d874b8370>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d874b94b0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d874b9120>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d874b8c70>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}]
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d879a5060>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d854f80d0>, 'is_max_threshold': True, 'threshold': 7.799999999999997, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856ce860>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856a5660>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8565aa70>, 'is_max_threshold': True, 'threshold': 16.2, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85605840>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856074c0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857d5780>, 'is_max_threshold': True, 'threshold': 2.25, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85758520>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85731060>, 'is_max_threshold': True, 'threshold': 1.5, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857ed570>, 'is_max_threshold': True, 'threshold': 0.09999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d859be2c0>, 'is_max_threshold': True, 'threshold': 0.75, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8596eb30>, 'is_max_threshold': True, 'threshold': 1.700000000000011, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8596c8b0>, 'is_max_threshold': True, 'threshold': 4.95, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85944460>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858f8460>, 'is_max_threshold': True, 'threshold': 1.8000000000001368, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85522980>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855490c0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85570a00>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85572500>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}]
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d87f70c10>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d853f39d0>, 'is_max_threshold': True, 'threshold': 7.7999999999979535, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855c83a0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855a11b0>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855510f0>, 'is_max_threshold': True, 'threshold': 16.2, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d854fc550>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856ce950>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856a5060>, 'is_max_threshold': True, 'threshold': 2.25, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85685f60>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857b45b0>, 'is_max_threshold': True, 'threshold': 1.5, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858e0f10>, 'is_max_threshold': True, 'threshold': 0.10000000000001137, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858b8a90>, 'is_max_threshold': True, 'threshold': 0.75, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85a9ddb0>, 'is_max_threshold': True, 'threshold': 1.7000000000000226, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86d9e440>, 'is_max_threshold': True, 'threshold': 4.95, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86d9e650>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86d9ecb0>, 'is_max_threshold': True, 'threshold': 1.7999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86d9dc30>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86d9d7e0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86d9d300>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86d9cd90>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}]
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86cd0cd0>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855c9330>, 'is_max_threshold': True, 'threshold': 7.799999999999997, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855a4730>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85575b40>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85525000>, 'is_max_threshold': True, 'threshold': 16.2, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856d02e0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856a5420>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85788310>, 'is_max_threshold': True, 'threshold': 2.25, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85680eb0>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857d9cc0>, 'is_max_threshold': True, 'threshold': 1.5, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858b69e0>, 'is_max_threshold': True, 'threshold': 0.09999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85892320>, 'is_max_threshold': True, 'threshold': 0.75, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85a764d0>, 'is_max_threshold': True, 'threshold': 1.700000000000011, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86c7a0b0>, 'is_max_threshold': True, 'threshold': 4.95, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86c7a5f0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86c7a830>, 'is_max_threshold': True, 'threshold': 1.8000000000001368, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86c79b40>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86c79600>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86c78f70>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d86c78bb0>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}]
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d879ddba0>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855193c0>, 'is_max_threshold': True, 'threshold': 7.800000000000409, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d854f1240>, 'is_max_threshold': True, 'threshold': 14.699999999998157, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856c0220>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85671270>, 'is_max_threshold': True, 'threshold': 16.2, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85620dc0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855fd6c0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d857cebc0>, 'is_max_threshold': True, 'threshold': 2.25, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85780910>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8572b760>, 'is_max_threshold': True, 'threshold': 1.5, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858d4760>, 'is_max_threshold': True, 'threshold': 0.10000000000004547, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8582d9f0>, 'is_max_threshold': True, 'threshold': 0.75, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d859dc8b0>, 'is_max_threshold': True, 'threshold': 1.7000000000005002, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d859b6020>, 'is_max_threshold': True, 'threshold': 4.949999999999863, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8598cd30>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8593d5d0>, 'is_max_threshold': True, 'threshold': 1.8000000000004093, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85541540>, 'is_max_threshold': True, 'threshold': 0.5999999999999999, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85569a80>, 'is_max_threshold': True, 'threshold': 0.5999999999999999, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855971f0>, 'is_max_threshold': True, 'threshold': 0.5999999999999999, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855bd030>, 'is_max_threshold': True, 'threshold': 0.5999999999999999, 'objective': 'rxn00062_c0'}]
# Tests: [{'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d87b9a4d0>, 'is_max_threshold': True, 'threshold': 1e-05, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85578490>, 'is_max_threshold': True, 'threshold': 7.8, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8554c9d0>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8552d5d0>, 'is_max_threshold': True, 'threshold': 12.45, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d856e31f0>, 'is_max_threshold': True, 'threshold': 16.2, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85690100>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85665300>, 'is_max_threshold': True, 'threshold': 14.7, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85632a10>, 'is_max_threshold': True, 'threshold': 2.25, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855ec610>, 'is_max_threshold': True, 'threshold': 1.0, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8579ada0>, 'is_max_threshold': True, 'threshold': 1.4999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d8574d030>, 'is_max_threshold': True, 'threshold': 0.09999999999990905, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d858cc730>, 'is_max_threshold': True, 'threshold': 0.75, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85879b40>, 'is_max_threshold': True, 'threshold': 1.700000000000125, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85825900>, 'is_max_threshold': True, 'threshold': 4.95, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85807550>, 'is_max_threshold': True, 'threshold': 0.5999999999999999, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d859a8280>, 'is_max_threshold': True, 'threshold': 1.7999999999999998, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855a6590>, 'is_max_threshold': True, 'threshold': 0.6000000000000681, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d855da080>, 'is_max_threshold': True, 'threshold': 0.6000000000000681, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d85404f40>, 'is_max_threshold': True, 'threshold': 0.6, 'objective': 'rxn00062_c0'}, {'media': <modelseedpy.core.msmedia.MSMedia object at 0x779d87b99a50>, 'is_max_threshold': True, 'threshold': 0.6000000000000681, 'objective': 'rxn00062_c0'}]

# %%
# %run util.py
import os
from pathlib import Path
from concurrent.futures import ProcessPoolExecutor, as_completed
from KBDatalakeApps.KBDatalakeUtils import run_phenotype_simulation

poplar_config = util.load("poplar_config")
kbversion = poplar_config["kbversion"]
max_phenotypes = poplar_config["max_phenotypes"]
max_phenotypes = None
output_dir = Path(poplar_config["output_dir"])
results_dir = output_dir / "models"

# Discover cobra model files on disk (independent of model reconstruction results)
cobra_files = sorted(results_dir.glob("*_cobra.json"))
pheno_items = []
phenopath = output_dir / "phenotypes"
phenopath.mkdir(parents=True, exist_ok=True)
data_path = os.path.join(poplar_config["module_path"], "KBDatalakeApps", "data")
for cobra_path in cobra_files:
    genome_id = cobra_path.name.replace("_cobra.json", "")
    pheno_output = str(phenopath / f"{genome_id}_phenosim.json")
    pheno_items.append((str(cobra_path), pheno_output))

print(f"--- Phenotype Simulation ({len(pheno_items)} models, 10 workers) ---")
with ProcessPoolExecutor(max_workers=10) as executor:
    futures = {
        executor.submit(run_phenotype_simulation, model_file, pheno_file, data_path, max_phenotypes, kbversion): model_file
        for model_file, pheno_file in pheno_items
    }
    for future in as_completed(futures):
        model_path = futures[future]
        try:
            result = future.result()
            status = "OK" if result.get('success') else f"FAIL: {str(result.get('error', '?'))[:80]}"
            print(f"  {Path(model_path).name}: {status}")
        except Exception as e:
            print(f"  {Path(model_path).name}: ERROR - {e}")

pheno_files = sorted(phenopath.glob("*_phenosim.json"))
print(f"\nDone. {len(pheno_files)} phenotype files saved in: {phenopath}")
# Out:
# [KBUtilLib] Failed to import rcsb_pdb_utils: ModuleNotFoundError: No module named 'aiohttp'
# modelseedpy 0.4.2
# 2026-02-13 07:47:31,379 - __main__.NotebookUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:31,380 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:31,381 - __main__.NotebookUtil - INFO - Notebook name: RunBERDLTablesPipeline
# 2026-02-13 07:47:31,382 - __main__.NotebookUtil - INFO - Notebook environment detected
# --- Phenotype Simulation (14 models, 10 workers) ---
# 2026-02-13 07:47:32,119 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,119 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,119 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,120 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,122 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:32,122 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,122 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:32,122 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:32,123 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:32,123 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,124 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:32,125 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:32,127 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,127 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,129 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:32,129 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:32,133 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,135 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:32,151 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 07:47:32,153 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 07:47:39,997 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-13 07:47:40,024 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-13 07:47:40,040 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-13 07:47:40,061 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-13 07:47:40,073 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-13 07:47:40,109 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-13 07:47:40,144 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-13 07:47:40,255 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-13 07:47:40,695 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-13 07:47:40,904 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
#   RS_GCF_010577805.1_cobra.json: OK
# 2026-02-13 08:24:23,480 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 08:24:23,482 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 08:24:23,483 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
#   RS_GCF_010577855.1_cobra.json: OK
# 2026-02-13 08:24:25,728 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 08:24:25,730 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 08:24:25,731 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
#   RS_GCF_000368685.1_cobra.json: OK
# 2026-02-13 08:24:26,908 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 08:24:26,910 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 08:24:26,911 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
#   RS_GCF_010577875.1_cobra.json: OK
# 2026-02-13 08:24:27,399 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-13 08:24:27,400 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-13 08:24:27,402 - KBDatalakeApps.KBDatalakeUtils.PhenotypeWorkerUtil - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c0' since it already exists.
# WARNING:modelseedpy.core.msatpcorrection:ATP tests not yet computed - running without allowing for model changes!
#   RS_GCF_010577895.1_cobra.json: OK
#   GB_GCA_002694305.1_cobra.json: OK
#   RS_GCF_000046845.1_cobra.json: OK
#   RS_GCF_000302115.1_cobra.json: OK
#   RS_GCF_001485005.1_cobra.json: OK
#   RS_GCF_000621045.1_cobra.json: OK
#   RS_GCF_010577925.1_cobra.json: OK
#   RS_GCF_900465415.1_cobra.json: OK
#   RS_GCF_010577955.1_cobra.json: OK
#   user_Acinetobacter_baylyi_ADP1_RAST_cobra.json: OK
#
# Done. 14 phenotype files saved in: /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/phenotypes

# %%
# %run util.py
import os
import shutil
from pathlib import Path

poplar_config = util.load("poplar_config")
output_dir = Path(poplar_config["output_dir"])
phenopath = output_dir / "phenotypes"
kbdl = util.create_kbdl_utils(poplar_config["reference_path"], poplar_config["module_path"], poplar_config["kbversion"])

pheno_files = sorted(phenopath.glob("*_phenosim.json"))
print(f"Found {len(pheno_files)} phenotype simulation files in {phenopath}")

# Build phenotype tables
print(f"\nBuilding phenotype tables...")
kbdl.build_phenotype_tables(
    output_dir=str(phenopath),
    phenosim_directory=str(phenopath),
    experiment_data_file=poplar_config["experimental_phenotype_datafile"],
    phenoset_file=poplar_config["phenotypeset_file"],
    fitness_mapping_dir=str(output_dir / "genome"),
    fitness_genomes_dir=poplar_config["fitness_genomes_dir"],
    model_data_dir=str(output_dir / "models"),
    reference_phenosim_dir=poplar_config["reference_phenosim_dir"],
    essential_genes_file=poplar_config["experimental_essentiality_datafile"]
)
# Out:
# [KBUtilLib] Failed to import rcsb_pdb_utils: ModuleNotFoundError: No module named 'aiohttp'
# modelseedpy 0.4.2
# 2026-02-14 15:30:34,492 - __main__.NotebookUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-14 15:30:34,493 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-14 15:30:34,495 - __main__.NotebookUtil - INFO - Notebook name: RunBERDLTablesPipeline
# 2026-02-14 15:30:34,495 - __main__.NotebookUtil - INFO - Notebook environment detected
# 2026-02-14 15:30:34,499 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-14 15:30:34,500 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# loading biochemistry database from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-14 15:30:42,618 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-14 15:30:43,226 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - CRITICAL - KBase version not set up for modeling!
# cobrakbase 0.4.0
# Found 14 phenotype simulation files in /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/phenotypes
#
# Building phenotype tables...
# Loaded 1813 condition-to-compound mappings from 37 fitness genomes
# Loaded model data for 14 genomes
# Loaded 13590 essential gene IDs from /home/chenry/Dropbox/Projects/KBDatalakeApps/data/essential_genes.csv
# Found 559 reference phenosim files from /home/chenry/GSP/reference_data/phenotype_data/phenosims/
# Processing 573 total phenosim files (1 user, 13 pangenome, 559 experiment)
#   Loaded fitness data for 2308 genes in user_Acinetobacter_baylyi_ADP1_RAST
# Added 43 experiment-only phenotype records from 1 genomes
# Saved model_performance.tsv with 573 genomes
# Saved genome_phenotypes.tsv with 121519 records
# Saved gene_phenotypes.tsv with 239584 records
# Built phenotype tables in /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/phenotypes

# %%
# %run util.py
from pathlib import Path

poplar_config = util.load("poplar_config")
output_dir = Path(poplar_config["output_dir"])
results_dir = output_dir / "models"
kbdl = util.create_kbdl_utils(poplar_config["reference_path"], poplar_config["module_path"], poplar_config["kbversion"])

# Build model tables from *_data.json files in the models directory
# Outputs genome_reactions.tsv and gene_reaction_data.tsv
print(f"Building model tables from {results_dir}...")
data_files = sorted(results_dir.glob("*_data.json"))
print(f"Found {len(data_files)} model data files")

kbdl.build_model_tables(model_path=str(results_dir))

# List output files
for tsv in sorted(results_dir.glob("*.tsv")):
    print(f"  {tsv.name} ({tsv.stat().st_size:,} bytes)")
# Out:
# 2026-02-14 15:32:08,938 - __main__.NotebookUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-14 15:32:08,939 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-14 15:32:08,941 - __main__.NotebookUtil - INFO - Notebook name: RunBERDLTablesPipeline
# 2026-02-14 15:32:08,942 - __main__.NotebookUtil - INFO - Notebook environment detected
# 2026-02-14 15:32:08,945 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-14 15:32:08,946 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-14 15:32:08,947 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - INFO - ModelSEED database loaded from /home/chenry/Dropbox/Projects/ModelSEEDDatabase
# 2026-02-14 15:32:09,537 - KBDatalakeApps.KBDatalakeUtils.KBDataLakeUtils - CRITICAL - KBase version not set up for modeling!
# Building model tables from /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/models...
# Found 14 model data files
# Processed 1286 reactions from RS_GCF_010577925.1_data.json
# Processed 1291 reactions from RS_GCF_010577875.1_data.json
# Processed 1291 reactions from RS_GCF_010577895.1_data.json
# Processed 1285 reactions from RS_GCF_010577955.1_data.json
# Processed 1282 reactions from RS_GCF_900465415.1_data.json
# Processed 1282 reactions from RS_GCF_000621045.1_data.json
# Processed 1282 reactions from RS_GCF_001485005.1_data.json
# Processed 1286 reactions from RS_GCF_000302115.1_data.json
# Processed 1284 reactions from RS_GCF_000368685.1_data.json
# Processed 1284 reactions from RS_GCF_010577855.1_data.json
# Processed 1284 reactions from RS_GCF_000046845.1_data.json
# Processed 1284 reactions from RS_GCF_010577805.1_data.json
# Processed 1279 reactions from user_Acinetobacter_baylyi_ADP1_RAST_data.json
# Processed 1284 reactions from GB_GCA_002694305.1_data.json
# Saved genome_reactions.tsv with 17984 rows to /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/models/genome_reactions.tsv
# Saved gene_reaction_data.tsv with 12311 rows to /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/models/gene_reaction_data.tsv
# Saved media_compositions.tsv with 70 rows to /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/models/media_compositions.tsv
#   gene_reaction_data.tsv (1,279,849 bytes)
#   genome_reactions.tsv (5,051,568 bytes)
#   media_compositions.tsv (1,785 bytes)

# %%
# %run util.py
import sys
from pathlib import Path

poplar_config = util.load("poplar_config")
output_dir = Path(poplar_config["output_dir"])

# Add lib to path so we can import build_berdl_db
sys.path.insert(0, str(Path.cwd().parent / "lib"))
from KBDatalakeApps.build_berdl_db import build_berdl_database

db_path = output_dir / "berdl_tables.db"
build_berdl_database(
    str(output_dir),
    str(db_path),
    reference_data_path=poplar_config["reference_path"],
)
# Out:
# 2026-02-14 15:32:12,355 - __main__.NotebookUtil - INFO - Loaded configuration from: /home/chenry/.kbutillib/config.yaml
# 2026-02-14 15:32:12,355 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /home/chenry/.kbase/token
# 2026-02-14 15:32:12,357 - __main__.NotebookUtil - INFO - Notebook name: RunBERDLTablesPipeline
# 2026-02-14 15:32:12,358 - __main__.NotebookUtil - INFO - Notebook environment detected
# Building BERDL database: /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/berdl_tables.db
# Input directory: /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST
# ============================================================
# Built 'genome' table: 14 rows
# Built 'genome_ani' table: 1 rows
# Loaded 3209 Bakta annotations from user_Acinetobacter_baylyi_ADP1_RAST_bakta.json
# Loaded 1913 KOfamscan annotations
# Loaded 606 PSORTb annotations
# Pangenome cluster assignment: 3187/3235 features assigned
# Built 'genome_features' table: 3235 rows
# Built 'missing_functions' table: 243 rows
#   Loaded 3617 enriched features for GB_GCA_002694305.1
#   Loaded 3273 enriched features for RS_GCF_000046845.1
#   Loaded 3465 enriched features for RS_GCF_000302115.1
#   Loaded 3275 enriched features for RS_GCF_000368685.1
#   Loaded 3318 enriched features for RS_GCF_000621045.1
#   Loaded 3311 enriched features for RS_GCF_001485005.1
#   Loaded 3285 enriched features for RS_GCF_010577805.1
#   Loaded 3276 enriched features for RS_GCF_010577855.1
#   Loaded 3292 enriched features for RS_GCF_010577875.1
#   Loaded 3279 enriched features for RS_GCF_010577895.1
#   Loaded 3322 enriched features for RS_GCF_010577925.1
#   Loaded 3617 enriched features for RS_GCF_010577955.1
#   Loaded 3424 enriched features for RS_GCF_900465415.1
# Built 'pan_genome_features' table: 43754 rows
# Built 'gene_reaction_data' table: 12311 rows
# Built 'genome_reactions' table: 17984 rows
# Built 'growth_phenotype_summary' table: 573 rows
# Built 'growth_phenotypes_detailed' table: 121519 rows
# Built 'gene_phenotypes' table: 239584 rows
# ============================================================
# Database complete: /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/berdl_tables.db
#   genome: 14 rows
#   genome_ani: 1 rows
#   genome_features: 3235 rows
#   missing_functions: 243 rows
#   pan_genome_features: 43754 rows
#   gene_reaction_data: 12311 rows
#   genome_reactions: 17984 rows
#   growth_phenotype_summary: 573 rows
#   growth_phenotypes_detailed: 121519 rows
#   gene_phenotypes: 239584 rows
#
# ======================================================================
# Generating ontology tables for: /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/berdl_tables.db
# ======================================================================
#
# 1. Loading RAST → seed.role mapper...
#    Warning: seed.json not found at /home/chenry/GSP/berdl_db/run_20250819_020438/parquet_files/seed.json
#    RAST → seed.role mapping will be skipped
#
# 2. Extracting ontology terms from tables: ['genome_features', 'pan_genome_features', 'genome_reactions', 'growth_phenotypes_detailed']
#    Processing 'genome_features': 3235 rows, columns: ['id', 'genome_id', 'contig_id', 'feature_id', 'length', 'start', 'end', 'strand', 'sequence', 'sequence_hash']...
#      RAST function column: rast_function
#    Processing 'pan_genome_features': 43754 rows, columns: ['id', 'genome_id', 'contig_id', 'feature_id', 'length', 'start', 'end', 'strand', 'sequence', 'sequence_hash']...
#      RAST function column: rast_function
#    Processing 'genome_reactions': 17984 rows, columns: ['genome_id', 'reaction_id', 'genes', 'equation_names', 'equation_ids', 'directionality', 'upper_bound', 'lower_bound', 'gapfilling_status', 'rich_media_flux']...
#    Processing 'growth_phenotypes_detailed': 121519 rows, columns: ['genome_id', 'phenotype_id', 'phenotype_name', 'class', 'simulated_objective', 'observed_objective', 'gap_count', 'gapfilled_reactions', 'reaction_count', 'transports_added']...
#
# 3. Skipping RAST → seed.role mapping (no mapper or no RAST functions)
#
#    Total unique terms: 8293
#      COG: 345
#      EC: 909
#      GO: 1423
#      KEGG: 1790
#      PFAM: 1937
#      SO: 1889
#
# 4. Enriching terms from local parquet files...
#
# 5. Extracting ontology relationships...
#
# 6. Adding EC column to ontology terms...
#    Warning: kegg_ko_ec_mapping.tsv not found at /home/chenry/GSP/berdl_db/run_20250819_020438/parquet_files/kegg_ko_ec_mapping.tsv
#    KEGG KO with EC: 0
#    GO terms with EC: 0
#    seed.role with EC: 0
#    seed.role with TC: 0
#    EC terms copied: 0
#    Total terms with ec column: 0
#
# 7. Creating ontology definitions...
#
# 8. Writing ontology tables to /home/chenry/BERDLFiles/scratch/Acinetobacter_baylyi_ADP1_RAST/berdl_tables.db...
#
# Error generating ontology tables: 'ontology_prefix'
# Traceback (most recent call last):
#   File "/home/chenry/Dropbox/Projects/KBDatalakeApps/lib/KBDatalakeApps/KBDatalakeUtils.py", line 2268, in generate_ontology_tables
#     terms_df = terms_df.sort_values(['ontology_prefix', 'identifier']).reset_index(drop=True)
#   File "/opt/env/modelseed_cplex/lib/python3.10/site-packages/pandas/core/frame.py", line 7172, in sort_values
#     keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#   File "/opt/env/modelseed_cplex/lib/python3.10/site-packages/pandas/core/frame.py", line 7172, in <listcomp>
#     keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#   File "/opt/env/modelseed_cplex/lib/python3.10/site-packages/pandas/core/generic.py", line 1911, in _get_label_or_level_values
#     raise KeyError(key)
# KeyError: 'ontology_prefix'
